# %%
# %matplotlib inline
import json
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np

# import some data to play with
iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
Y = iris.target

x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5

plt.figure(2, figsize=(8, 6))
plt.clf()

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())

# To getter a better understanding of interaction of the dimensions
# plot the first three PCA dimensions
fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
X_reduced = PCA(n_components=3).fit_transform(iris.data)
ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], c=Y,
           cmap=plt.cm.Paired)
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])



plt.figure(2, figsize=(8, 6))
plt.clf()

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')


plt.figure(3, figsize=(8, 6))
plt.clf()

# Plot the training points
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=Y, cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')


plt.show()

# print iris.data
# print Y
print np.cov(iris.data.transpose())
print np.cov(X_reduced.transpose())
# Out:
# [[ 0.68569351 -0.03926846  1.27368233  0.5169038 ]
#  [-0.03926846  0.18800403 -0.32171275 -0.11798121]
#  [ 1.27368233 -0.32171275  3.11317942  1.29638747]
#  [ 0.5169038  -0.11798121  1.29638747  0.58241432]]
# [[  4.22484077e+00  -1.73807924e-16   6.11463603e-17]
#  [ -1.73807924e-16   2.42243572e-01  -1.89941375e-17]
#  [  6.11463603e-17  -1.89941375e-17   7.85239081e-02]]

# %%
# Plot the training points
from sklearn import svm
from sklearn import preprocessing

Xtrans=iris.data
colors=np.array( ['r','b','g'] )
plt.figure()
plt.scatter(Xtrans[:, 0], Xtrans[:, 1], c=colors[Y], cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.figure()
plt.scatter(Xtrans[:, 1], Xtrans[:, 2], c=colors[Y], cmap=plt.cm.Paired)
plt.xlabel('Sepal Width')
plt.ylabel('Petal Length')

plt.figure()
plt.scatter(Xtrans[:, 2], Xtrans[:, 3], c=colors[Y], cmap=plt.cm.Paired)
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')

plt.figure()
plt.scatter(Xtrans[:, 0], Xtrans[:, 2], c=colors[Y], cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Petal Length')


plt.figure()
plt.scatter(Xtrans[:, 0], Xtrans[:, 3], c=colors[Y], cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Petal Width')

plt.figure()
plt.scatter(Xtrans[:, 1], Xtrans[:, 3], c=colors[Y], cmap=plt.cm.Paired)
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn import linear_model
from sklearn.cross_validation import train_test_split
from sklearn import metrics
ind=[0,1]
DATA=iris.data[:,ind]

X_train, X_test, y_train, y_test = train_test_split( DATA, Y, test_size=0.33, random_state=42)

# Sepal Length, Sepal Width, Petal Length and Petal Width

scaler = preprocessing.StandardScaler().fit(X_train)
X_train=scaler.transform(X_train)

# X_train, X_test, y_train, y_test
# ind=np.logical_or(y_train==1,y_train==0)
# features=X_train[ind]
# labels=y_train[ind]


clf_sgd = linear_model.SGDClassifier(shuffle=True,verbose=0)
clf_sgd.fit(X_train, y_train)
print "coef"
print clf_sgd.coef_
print "intercept"
print clf_sgd.intercept_
print "predict"
y_test_predict=clf_sgd.predict(scaler.transform(X_test) )
print y_test_predict
print clf_sgd.decision_function(scaler.transform(X_test[1,:]) )

print "----"
xmin=np.amin(X_train,axis=0)
xmax=np.amax(X_train,axis=0)


print metrics.accuracy_score(y_test,y_test_predict)
print metrics.classification_report(y_test,y_test_predict,target_names=iris.target_names)
print metrics.confusion_matrix(y_test,y_test_predict)


colors=np.array( ['r','b','g'] )

plt.figure()
plt.scatter(X_train[:, 0], X_train[:, 1], c=colors[y_train], cmap=plt.cm.Paired)
cls=0
xs=np.linspace(xmin[0],xmax[0],100)
ys=(-xs*clf_sgd.coef_[cls,0]-clf_sgd.intercept_[cls])/clf_sgd.coef_[cls,1]
plt.plot(xs,ys)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.figure()
plt.scatter(X_train[:, 0], X_train[:, 1], c=colors[y_train], cmap=plt.cm.Paired)
cls=1
xs=np.linspace(xmin[0],xmax[0],100)
ys=(-xs*clf_sgd.coef_[cls,0]-clf_sgd.intercept_[cls])/clf_sgd.coef_[cls,1]
plt.plot(xs,ys)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.figure()
plt.scatter(X_train[:, 0], X_train[:, 1], c=colors[y_train], cmap=plt.cm.Paired)
cls=2
xs=np.linspace(xmin[0],xmax[0],100)
ys=(-xs*clf_sgd.coef_[cls,0]-clf_sgd.intercept_[cls])/clf_sgd.coef_[cls,1]
plt.plot(xs,ys)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')




# print clf_sgd.
# clf_svclinear = svm.SVC(kernel='linear')

# print clf_svclinear.fit(features, labels)
# print clf_svclinear.predict([[2., 2.,2,2],[-3,0,4,5]])
# Out:
# coef
# [[-32.5453905   11.57079012]
#  [  4.81559416 -12.89224525]
#  [ 19.26237662  -3.22306131]]
# intercept
# [-26.23217932  -2.37974083  -2.88946928]
# predict
# [1 0 2 2 2 0 1 2 1 1 2 0 0 0 0 2 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 2 0 0 1 2
#  0 0 0 1 2 2 0 0 1 2 2 2 2]
# [[  0.46406579 -27.77402291 -11.73653919]]
# ----
# 0.8
#              precision    recall  f1-score   support
#
#      setosa       1.00      1.00      1.00        19
#  versicolor       0.78      0.47      0.58        15
#   virginica       0.64      0.88      0.74        16
#
# avg / total       0.82      0.80      0.79        50
#
# [[19  0  0]
#  [ 0  7  8]
#  [ 0  2 14]]
# /home/venkat/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:646: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
# ...

# %%
from sklearn import svm
clf_svc = svm.SVC(kernel='linear')
clf_svc.fit(X_train, y_train)
y_test_predict=clf_svc.predict(scaler.transform(X_test) )
print metrics.accuracy_score(y_test,y_test_predict)
print metrics.classification_report(y_test,y_test_predict,target_names=iris.target_names)
print metrics.confusion_matrix(y_test,y_test_predict)
print clf_svc.coef_
print clf_svc.intercept_
# print clf_svc.support_vectors_
# Out:
# 0.78
#              precision    recall  f1-score   support
#
#      setosa       1.00      1.00      1.00        19
#  versicolor       0.67      0.53      0.59        15
#   virginica       0.63      0.75      0.69        16
#
# avg / total       0.78      0.78      0.78        50
#
# [[19  0  0]
#  [ 0  8  7]
#  [ 0  4 12]]
# [[-2.03566096  1.18241068]
#  [-1.86889495  0.74462039]
#  [-1.03895177 -0.51743449]]
# [-1.50960695 -0.82170223  0.47373431]

# %%
rbf_svc = svm.SVC(kernel='rbf')
print rbf_svc.fit(X_train, y_train)
print rbf_svc.gamma
y_test_predict=rbf_svc.predict(scaler.transform(X_test) )
print metrics.accuracy_score(y_test,y_test_predict)
print metrics.classification_report(y_test,y_test_predict,target_names=iris.target_names)
print metrics.confusion_matrix(y_test,y_test_predict)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# auto
# 0.72
#              precision    recall  f1-score   support
#
#      setosa       1.00      1.00      1.00        19
#  versicolor       0.53      0.53      0.53        15
#   virginica       0.56      0.56      0.56        16
#
# avg / total       0.72      0.72      0.72        50
#
# [[19  0  0]
#  [ 0  8  7]
#  [ 0  7  9]]

# %%
poly_svc = svm.SVC(kernel='poly',degree=4)
poly_svc.fit(X_train, y_train)
y_test_predict=poly_svc.predict(scaler.transform(X_test) )
print metrics.accuracy_score(y_test,y_test_predict)
print metrics.classification_report(y_test,y_test_predict,target_names=iris.target_names)
print metrics.confusion_matrix(y_test,y_test_predict)
# Out:
# 0.58
#              precision    recall  f1-score   support
#
#      setosa       0.76      0.68      0.72        19
#  versicolor       0.45      0.87      0.59        15
#   virginica       0.75      0.19      0.30        16
#
# avg / total       0.67      0.58      0.55        50
#
# [[13  5  1]
#  [ 2 13  0]
#  [ 2 11  3]]

# %%
lin_clf = svm.LinearSVC()
lin_clf.fit(X_train, y_train)
print lin_clf.get_params(deep=True)
y_test_predict=lin_clf.predict(scaler.transform(X_test) )
print metrics.accuracy_score(y_test,y_test_predict)
print metrics.classification_report(y_test,y_test_predict,target_names=iris.target_names)
print metrics.confusion_matrix(y_test,y_test_predict)
# Out:
# {'loss': 'squared_hinge', 'C': 1.0, 'verbose': 0, 'intercept_scaling': 1, 'fit_intercept': True, 'max_iter': 1000, 'penalty': 'l2', 'multi_class': 'ovr', 'random_state': None, 'dual': True, 'tol': 0.0001, 'class_weight': None}
# 0.82
#              precision    recall  f1-score   support
#
#      setosa       1.00      1.00      1.00        19
#  versicolor       0.80      0.53      0.64        15
#   virginica       0.67      0.88      0.76        16
#
# avg / total       0.83      0.82      0.81        50
#
# [[19  0  0]
#  [ 0  8  7]
#  [ 0  2 14]]

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB

gnb = GaussianNB()
gnb.fit(X_train, y_train)
print gnb.get_params(deep=True)
y_test_predict=gnb.predict(scaler.transform(X_test) )
print metrics.accuracy_score(y_test,y_test_predict)
print metrics.classification_report(y_test,y_test_predict,target_names=iris.target_names)
print metrics.confusion_matrix(y_test,y_test_predict)
# Out:
# {}
# 0.8
#              precision    recall  f1-score   support
#
#      setosa       1.00      1.00      1.00        19
#  versicolor       0.73      0.53      0.62        15
#   virginica       0.65      0.81      0.72        16
#
# avg / total       0.81      0.80      0.80        50
#
# [[19  0  0]
#  [ 0  8  7]
#  [ 0  3 13]]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(solver="svd", store_covariance=True)
lda.fit(X_train, y_train)
print lda.get_params(deep=True)
y_test_predict=lda.predict(scaler.transform(X_test) )
print metrics.accuracy_score(y_test,y_test_predict)
print metrics.classification_report(y_test,y_test_predict,target_names=iris.target_names)
print metrics.confusion_matrix(y_test,y_test_predict)
# Out:
# {'solver': 'svd', 'priors': None, 'n_components': None, 'tol': 0.0001, 'shrinkage': None, 'store_covariance': True}
# 0.82
#              precision    recall  f1-score   support
#
#      setosa       0.95      1.00      0.97        19
#  versicolor       0.80      0.53      0.64        15
#   virginica       0.70      0.88      0.78        16
#
# avg / total       0.82      0.82      0.81        50
#
# [[19  0  0]
#  [ 1  8  6]
#  [ 0  2 14]]

# %%
qda = QuadraticDiscriminantAnalysis(store_covariances=True)
qda.fit(X_train, y_train)
print qda.get_params(deep=True)
y_test_predict=qda.predict(scaler.transform(X_test) )
print metrics.accuracy_score(y_test,y_test_predict)
print metrics.classification_report(y_test,y_test_predict,target_names=iris.target_names)
print metrics.confusion_matrix(y_test,y_test_predict)
# Out:
# {'priors': None, 'reg_param': 0.0, 'tol': 0.0001, 'store_covariances': True}
# 0.78
#              precision    recall  f1-score   support
#
#      setosa       1.00      1.00      1.00        19
#  versicolor       0.67      0.53      0.59        15
#   virginica       0.63      0.75      0.69        16
#
# avg / total       0.78      0.78      0.78        50
#
# [[19  0  0]
#  [ 0  8  7]
#  [ 0  4 12]]

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X_train, y_train)
print neigh.get_params(deep=True)
y_test_predict=neigh.predict(scaler.transform(X_test) )
print metrics.accuracy_score(y_test,y_test_predict)
print metrics.classification_report(y_test,y_test_predict,target_names=iris.target_names)
print metrics.confusion_matrix(y_test,y_test_predict)
# Out:
# {'n_neighbors': 3, 'n_jobs': 1, 'algorithm': 'auto', 'metric': 'minkowski', 'metric_params': None, 'p': 2, 'weights': 'uniform', 'leaf_size': 30}
# 0.82
#              precision    recall  f1-score   support
#
#      setosa       1.00      1.00      1.00        19
#  versicolor       0.80      0.53      0.64        15
#   virginica       0.67      0.88      0.76        16
#
# avg / total       0.83      0.82      0.81        50
#
# [[19  0  0]
#  [ 0  8  7]
#  [ 0  2 14]]

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(random_state=0)
dtc.fit(X_train, y_train)
print json.dumps(dtc.get_params(deep=True), indent=2)
y_test_predict=dtc.predict(scaler.transform(X_test) )
print metrics.accuracy_score(y_test,y_test_predict)
print metrics.classification_report(y_test,y_test_predict,target_names=iris.target_names)
print metrics.confusion_matrix(y_test,y_test_predict)
# Out:
# {
#   "presort": false,
#   "splitter": "best",
#   "max_leaf_nodes": null,
#   "min_samples_leaf": 1,
#   "min_samples_split": 2,
#   "min_weight_fraction_leaf": 0.0,
#   "criterion": "gini",
#   "random_state": 0,
#   "max_features": null,
#   "max_depth": null,
#   "class_weight": null
# }
# 0.7
#              precision    recall  f1-score   support
#
#      setosa       1.00      0.95      0.97        19
#  versicolor       0.50      0.53      0.52        15
#   virginica       0.56      0.56      0.56        16
#
# avg / total       0.71      0.70      0.70        50
#
# [[18  1  0]
#  [ 0  8  7]
#  [ 0  7  9]]
